# %%
pip install tweepy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import tweepy

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret_key)
auth.set_access_token(access_key,access_secret_key)

# %%
api = tweepy.API(auth)

# %%
consumer_key = "UODXYhgdi5iSUkb8B3BIludZ0"
consumer_secret_key = "JxXDM9xoSjFGXlsWWPRLFGcHeahOKpx7W9uAKWsM0BVHOhyN8f"
access_key = "964513788606189570-oIVsHe3QKcReJDE3Z2lSiFjga9CTcUc"
access_secret_key = "mQzFGI4dIfftUGbzND5ZB67ddCkZfYMFMtG0OsoamDyVi"

# %%
tweets = api.home_timeline()
for tweet in tweets:
    print('{real_name} (@{name}) said {tweet}\n\n'.format(
        real_name=tweet.author.name, name=tweet.author.screen_name,
        tweet=tweet.text))
# Out:
# NIA SHARMA (@Theniasharma) said ✨✨✨ https://t.co/SPlJGwpqpT
#
#
# PMO India (@PMOIndia) said मेरा आग्रह है, अगले 25 वर्षों के लिए विश्व भारती के विद्यार्थी मिलकर एक विजन डॉक्यूमेंट बनाएं।
#
# वर्ष 2047 में, जब… https://t.co/PwRXGS9n3f
#
#
# PMO India (@PMOIndia) said भारत जो है, जो मानवता, जो आत्मीयता, जो विश्व कल्याण की भावना हमारे रक्त के कण-कण में है, उसका ऐहसास बाकी देशों को क… https://t.co/xR4BQ0qLsJ
#
#
# PMO India (@PMOIndia) said इस वर्ष हम अपनी आजादी के 75वें वर्ष में प्रवेश कर रहे हैं।
#
# विश्व भारती के प्रत्येक विद्यार्थी की तरफ से देश को सब… https://t.co/1VgTGESddv
#
#
# PMO India (@PMOIndia) said बंगाल ने अतीत में भारत के समृद्ध ज्ञान-विज्ञान को आगे बढ़ाने में देश को नेतृत्व दिया।
#
# बंगाल, एक भारत, श्रेष्ठ भारत… https://t.co/0qgUDuxrHA
#
#
# PMO India (@PMOIndia) said भारत की आत्मनिर्भरता, देश की बेटियों के आत्मविश्वास के बिना संभव नहीं है।
#
# नई राष्ट्रीय शिक्षा नीति में पहली बार Ge… https://t.co/sPlqHFjHJ1
#
#
# ...

# %%
print(tweets)
# Out:
# [Status(_api=<tweepy.api.API object at 0x7ff206c93070>, _json={'created_at': 'Fri Feb 19 06:42:03 +0000 2021', 'id': 1362653656848326660, 'id_str': '1362653656848326660', 'text': '✨✨✨ https://t.co/SPlJGwpqpT', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [], 'media': [{'id': 1362653646085758979, 'id_str': '1362653646085758979', 'indices': [4, 27], 'media_url': 'http://pbs.twimg.com/media/EukeRX7VIAMJfad.jpg', 'media_url_https': 'https://pbs.twimg.com/media/EukeRX7VIAMJfad.jpg', 'url': 'https://t.co/SPlJGwpqpT', 'display_url': 'pic.twitter.com/SPlJGwpqpT', 'expanded_url': 'https://twitter.com/Theniasharma/status/1362653656848326660/photo/1', 'type': 'photo', 'sizes': {'small': {'w': 407, 'h': 680, 'resize': 'fit'}, 'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'large': {'w': 1225, 'h': 2048, 'resize': 'fit'}, 'medium': {'w': 718, 'h': 1200, 'resize': 'fit'}}}]}, 'extended_entities': {'media': [{'id': 1362653646085758979, 'id_str': '13
# ...

# %%
api.status()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-fe759c3f57d6> in <module>
# ----> 1 api.status()
#
# AttributeError: 'API' object has no attribute 'status'

# %%
print(api)

# %%
me = api.me()

# %%
me.screen_name
# Out:
# 'PrachiVavhal'

# %%
api.update_status('Just a demo')
# Out:
# Status(_api=<tweepy.api.API object at 0x7f588eeb93c8>, _json={'created_at': 'Thu Feb 11 05:46:46 +0000 2021', 'id': 1359740640683302912, 'id_str': '1359740640683302912', 'text': 'Just a demo', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, 'source': '', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 964513788606189570, 'id_str': '964513788606189570', 'name': 'Prachi Vavhal', 'screen_name': 'PrachiVavhal', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 0, 'friends_count': 0, 'listed_count': 0, 'created_at': 'Fri Feb 16 14:56:21 +0000 2018', 'favourites_count': 0, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 1, 'lang': None, 'contributors_enabled': False, 'is_translator': Fal
# ...

# %%
me.description
# Out:
# 'Student'

# %%
user = api.get_user('PrachiVavhal')
location = user.location
uid = user.id
print('user id is',uid)
print('location is:',location)
print('name of user:',user.name)
# Out:
# user id is 964513788606189570
# location is: Nashik
# name of user: Prachi Vavhal
